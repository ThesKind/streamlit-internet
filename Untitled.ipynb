# %%
# Tentukan Library Yang Digunakan
import numpy as np 
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
# Load Dataset
internet_dataset = pd.read_csv("data-pembayaran.csv")

# %%
internet_dataset.head(5)
# Out:
#    TAGIHAN BULANAN JANUARI    BAYAR  TANGGAL BAYAR  JENIS KELAMIN  \
# 0                    100000  100000             27              1
# 1                    100000  100000             27              1
# 2                    100000  100000             27              0
# 3                    300000  300000             27              0
# 4                    125000  125000             27              0
#
#    STATUS BAYAR
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
internet_dataset.shape
# Out:
# (108, 5)

# %%
internet_dataset['STATUS BAYAR'].value_counts()
# Out:
# STATUS BAYAR
# 1    71
# 0    37
# Name: count, dtype: int64

# %%
# Memisahkan Data Dan Label
X = internet_dataset.drop(columns='STATUS BAYAR', axis=1)
Y = internet_dataset['STATUS BAYAR']

# %%
print(X)
# Out:
#      TAGIHAN BULANAN JANUARI    BAYAR  TANGGAL BAYAR  JENIS KELAMIN
# 0                      100000  100000             27              1
# 1                      100000  100000             27              1
# 2                      100000  100000             27              0
# 3                      300000  300000             27              0
# 4                      125000  125000             27              0
# ..                        ...     ...            ...            ...
# 103                    125000  125000             27              1
# 104                    100000  100000             29              1
# 105                    125000  125000             27              1
# 106                    100000  100000             27              1
# 107                    125000  125000             29              0
#
# [108 rows x 4 columns]

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 103    1
# 104    0
# 105    1
# 106    0
# 107    1
# Name: STATUS BAYAR, Length: 108, dtype: int64

# %%
# Standarisasi Data
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standarized_data = scaler.transform(X)

# %%
print(standarized_data)
# Out:
# [[-0.57259386 -0.46290923 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923 -0.70710678 -1.50755672]
#  [ 1.46497244  1.01730384 -0.70710678 -1.50755672]
#  [-0.31789808 -0.27788259 -0.70710678 -1.50755672]
#  [-0.31789808 -0.27788259  1.41421356  0.66332496]
#  [-0.57259386 -0.83296249 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923  1.41421356 -1.50755672]
#  [-0.06320229 -0.09285596 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923  1.41421356  0.66332496]
#  [ 2.48375559  1.01730384 -0.70710678  0.66332496]
#  [-0.31789808 -0.27788259  1.41421356  0.66332496]
#  [-0.57259386 -0.46290923  1.41421356  0.66332496]
#  [-0.06320229 -0.09285596 -0.70710678 -1.50755672]
#  [-0.57259386 -0.46290923  1.41421356 -1.50755672]
#  [-0.57259386 -0.46290923  1.41421356 -1.50755672]
#  [ 1.97436401  1.38735711  1.41421356  0.66332496]
#  [-0.31789808 -0.27788259  1.41421356  0.66332496]
# ...

# %%
X = standarized_data
Y = internet_dataset['STATUS BAYAR']

# %%
print(X)
print(Y)
# Out:
# [[-0.57259386 -0.46290923 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923 -0.70710678 -1.50755672]
#  [ 1.46497244  1.01730384 -0.70710678 -1.50755672]
#  [-0.31789808 -0.27788259 -0.70710678 -1.50755672]
#  [-0.31789808 -0.27788259  1.41421356  0.66332496]
#  [-0.57259386 -0.83296249 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923  1.41421356 -1.50755672]
#  [-0.06320229 -0.09285596 -0.70710678  0.66332496]
#  [-0.57259386 -0.46290923  1.41421356  0.66332496]
#  [ 2.48375559  1.01730384 -0.70710678  0.66332496]
#  [-0.31789808 -0.27788259  1.41421356  0.66332496]
#  [-0.57259386 -0.46290923  1.41421356  0.66332496]
#  [-0.06320229 -0.09285596 -0.70710678 -1.50755672]
#  [-0.57259386 -0.46290923  1.41421356 -1.50755672]
#  [-0.57259386 -0.46290923  1.41421356 -1.50755672]
#  [ 1.97436401  1.38735711  1.41421356  0.66332496]
#  [-0.31789808 -0.27788259  1.41421356  0.66332496]
# ...

# %%
# Memisahkan Data Training Dan Data Testing
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (108, 4) (86, 4) (22, 4)

# %%
# Membuat Data Latih Menggunakan Algoritma SVM
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# Membuat Evaluasi Unutuk Mengukur Tingkat Akurasi 
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Akurasi Data Training Adalah = ', training_data_accuracy)
# Out:
# Akurasi Data Training Adalah =  0.9651162790697675

# %%
X_test_prediction = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Akurasi Data Testing Adalah = ', test_data_accuracy)
# Out:
# Akurasi Data Testing Adalah =  1.0

# %%
# Membuat Model Prediksi
input_data = (100000, 100000, 27, 1)

input_data_as_numpy_array = np.array(input_data)

input_data_reshape = input_data_as_numpy_array.reshape(1, -1)

std_data = scaler.transform(input_data_reshape)
print(std_data)

prediction = classifier.predict(std_data)
print(prediction)

if (prediction[0] == 0):
    print('Terlambat')
else :
    print('Tepat')
# Out:
# [[-0.57259386 -0.46290923 -0.70710678  0.66332496]]
# [1]
# Tepat

# %%
# Simpan Model
import pickle

# %%
filename = 'internet_model.sav'
pickle.dump(classifier, open(filename,'wb'))
